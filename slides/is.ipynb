# %% [markdown]
# <center>
#
# # L'impatto
# ## su studio (e lavoro)
#
# </center>

# %% [markdown]
# ## *Non fa scienza, sanza lo ritenere, avere inteso*
#
# ### Motori di ricerca
#
# <ul>
# <li class="fragment"><a href="https://www.science.org/doi/10.1126/science.1207745">Cognitive Consequences of Having Information at Our Fingertips</a>, Science (2011);</li>
# </ul>

# %% [markdown]
# ### Intelligenza artificiale generativa
#
# <ul>
# <li class="fragment"><a href="https://dx.doi.org/10.2139/ssrn.4895486">Generative AI Can Harm Learning</a>, Wharton (2024);</li>
# <li class="fragment"><a href="https://arxiv.org/abs/2506.08872">Accumulation of Cognitive Debt when Using an AI Assistant for Essay Writing Task</a>, arXiv (2025).</li>
# </ul>

# %% [markdown]
# ## Il mondo del lavoro
#
# <a href="https://www.anthropic.com/research/labor-market-impacts"><img alt="Work" src="./media/work.jpg" style="width: 60%; margin: auto; display: block;" /></a>

# %% [markdown]
# <center style="font-size: 1.5em;">
#   <a href="se.html">Motori di ricerca</a>
# </center>
